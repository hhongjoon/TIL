# %% [markdown]
# # 가상화폐 시세 판단하기

# %% [markdown]
# > 최고가와 최저가의 차이를 변동폭으로 정의할 때 (시가 + 변동폭)이 최고가 보다 높을 경우 "상승장", 그렇지 않은 경우 "하락장" 문자열을 출력하라.
#
# |Key Name        |     Description|
# |---|---|
# |opeing_price    |최근 24시간 내 시작 거래금액|
# |closing_price   |최근 24시간 내 마지막 거래금액|
# |min_price       |최근 24시간 내 최저 거래금액|
# |max_price       |최근 24시간 내 최고 거래금액|

# %%
from pprint import pprint
import requests
btc = requests.get('https://api.bithumb.com/public/ticker/btc').json()['data']
pprint(btc)
# Out:
# {'24H_fluctate': '-47000',
#  '24H_fluctate_rate': '-1.22',
#  'average_price': '3816259.2784',
#  'buy_price': '3779000',
#  'closing_price': '3780000',
#  'date': '1548743301089',
#  'max_price': '3850000',
#  'min_price': '3757000',
#  'opening_price': '3827000',
#  'sell_price': '3780000',
#  'units_traded': '3485.66240732',
#  'volume_1day': '3485.66240732',
#  'volume_7day': '21558.95161339'}

# %%
# 아래에 코드를 작성하세요.
fluc = int(btc['max_price'])-int(btc['min_price'])

if int(btc['closing_price'])+fluc > int(btc['max_price']):
    print('상승장')
else:
    print('하락장')
# Out:
# 상승장

# %% [markdown]
# ## 모든 가상화폐 시세 판단하기
#
#
# > currrency dictionary에 담겨있는 모든 가상화폐 거래내역을 바탕으로 출력하라.
# >
# > 예외 처리에 유의하세요.
#
#
#
# ```
# 예시 출력)
# BTC 상승장
# ETH 상승장
# DASH 상승장
# LTC 하락장
# ETC 하락장
# XRP 상승장
# BCH 상승장
# ...
# ```

# %%
currency = requests.get('https://api.bithumb.com/public/ticker/all').json()['data']
pprint(currency)
# Out:
# {'ABT': {'24H_fluctate': '-3.6',
#          '24H_fluctate_rate': '-4.99',
#          'average_price': '70.1842',
#          'buy_price': '70.5',
#          'closing_price': '68.5',
#          'max_price': '74.8',
#          'min_price': '66',
#          'opening_price': '72.1',
#          'sell_price': '72.5',
#          'units_traded': '360042.23410345',
#          'volume_1day': '360042.23410345',
#          'volume_7day': '5675249.397032159682731299'},
#  'ADA': {'24H_fluctate': '-1.4',
#          '24H_fluctate_rate': '-3.27',
#          'average_price': '42.2126',
#          'buy_price': '41.3',
#          'closing_price': '41.3',
#          'max_price': '43.3',
#          'min_price': '41.1',
#          'opening_price': '42.7',
#          'sell_price': '41.6',
#          'units_traded': '8417997.15648409',
#          'volume_1day': '8417997.15648409',
#          'volume_7day': '51908472.91042435'},
#  'ADD': [],
#  'AE': {'24H_fluctate': '3',
#         '24H_fluctate_rate': '0.75',
#         'average_price': '406.7645',
#         'buy_price': '403',
#         'closing_price': '403',
#         'max_price': '417',
#         'min_price': '399',
#         'opening_price': '400',
#         'sell_price': '404',
#         'units_traded': '514055.89438079',
#         'volume_1day': '514055.89438079',
#         'volume_7day': '5632136.78212291074057475'},
#  'AMO': {'24H_fluctate': '0.03',
#          '24H_fluctate_rate': '4.68',
#          'average_price': '0.6644',
#          'buy_price': '0.65',
#          'closing_price': '0.67',
#          'max_price': '0.7',
#          'min_price': '0.63',
#          'opening_price': '0.64',
#          'sell_price': '0.67',
#          'units_traded': '201615896.21526863',
#          'volume_1day': '201615896.21526863',
#          'volume_7day': '2894839561.655431449158818423'},
#  'APIS': {'24H_fluctate': '0.18',
#           '24H_fluctate_rate': '9.23',
#           'average_price': '2.1208',
#           'buy_price': '2.13',
#           'closing_price': '2.13',
#           'max_price': '2.34',
#           'min_price': '1.88',
#           'opening_price': '1.95',
#           'sell_price': '2.14',
#           'units_traded': '857423871.5468877',
#           'volume_1day': '857423871.5468877',
#           'volume_7day': '29268087542.40354204471716559'},
#  'ARN': {'24H_fluctate': '-3',
#          '24H_fluctate_rate': '-1.07',
#          'average_price': '285.8243',
#          'buy_price': '274',
#          'closing_price': '276',
#          'max_price': '308',
#          'min_price': '271',
#          'opening_price': '279',
#          'sell_price': '281',
#          'units_traded': '315600.55897867',
#          'volume_1day': '315600.55897867',
#          'volume_7day': '1513541.67601822'},
#  'BAT': {'24H_fluctate': '-7',
#          '24H_fluctate_rate': '-5.46',
#          'average_price': '126.3169',
#          'buy_price': '121',
#          'closing_price': '121',
#          'max_price': '136',
#          'min_price': '121',
#          'opening_price': '128',
#          'sell_price': '124',
#          'units_traded': '433509.65519412',
#          'volume_1day': '433509.65519412',
#          'volume_7day': '1904177.084712992227622529'},
#  'BCD': {'24H_fluctate': '-9',
#          '24H_fluctate_rate': '-1.15',
#          'average_price': '785.0378',
#          'buy_price': '772',
#          'closing_price': '770',
#          'max_price': '803',
#          'min_price': '768',
#          'opening_price': '779',
#          'sell_price': '792',
#          'units_traded': '27057.55150635',
#          'volume_1day': '27057.55150635',
#          'volume_7day': '344475.24282483'},
#  'BCH': {'24H_fluctate': '-3300',
#          '24H_fluctate_rate': '-2.67',
#          'average_price': '122079.4579',
#          'buy_price': '120000',
#          'closing_price': '120000',
#          'max_price': '125800',
#          'min_price': '117000',
#          'opening_price': '123300',
#          'sell_price': '120200',
#          'units_traded': '30068.12019975',
#          'volume_1day': '30068.12019975',
#          'volume_7day': '174816.75152541'},
#  'BHPC': {'24H_fluctate': '7',
#           '24H_fluctate_rate': '0.93',
#           'average_price': '737.3941',
#           'buy_price': '748',
#           'closing_price': '753',
#           'max_price': '757',
#           'min_price': '722',
#           'opening_price': '746',
#           'sell_price': '753',
#           'units_traded': '49800.68952767',
#           'volume_1day': '49800.68952767',
#           'volume_7day': '1658662.019945876963579857'},
#  'BLACK': [],
#  'BSV': {'24H_fluctate': '-3850',
#          '24H_fluctate_rate': '-5.25',
#          'average_price': '71288.622',
#          'buy_price': '69250',
#          'closing_price': '69400',
#          'max_price': '74000',
#          'min_price': '68400',
#          'opening_price': '73250',
#          'sell_price': '69400',
#          'units_traded': '19767.10898594',
#          'volume_1day': '19767.10898594',
#          'volume_7day': '78160.708861'},
#  'BTC': {'24H_fluctate': '-46000',
#          '24H_fluctate_rate': '-1.20',
#          'average_price': '3816027.6944',
#          'buy_price': '3778000',
#          'closing_price': '3778000',
#          'max_price': '3850000',
#          'min_price': '3757000',
#          'opening_price': '3824000',
#          'sell_price': '3781000',
#          'units_traded': '3500.24360732',
#          'volume_1day': '3500.24360732',
#          'volume_7day': '21549.82545286'},
#  'BTG': {'24H_fluctate': '140',
#          '24H_fluctate_rate': '1.34',
#          'average_price': '10469.0571',
#          'buy_price': '10520',
#          'closing_price': '10580',
#          'max_price': '10790',
#          'min_price': '10110',
#          'opening_price': '10440',
#          'sell_price': '10590',
#          'units_traded': '18877079.31446955',
#          'volume_1day': '18877079.31446955',
#          'volume_7day': '134430765.25266975'},
#  'BZNT': {'24H_fluctate': '0.1',
#           '24H_fluctate_rate': '0.37',
#           'average_price': '27.6017',
#           'buy_price': '27.1',
#           'closing_price': '27.1',
#           'max_price': '29.3',
#           'min_price': '26.6',
#           'opening_price': '27',
#           'sell_price': '27.3',
#           'units_traded': '11260755.65673499',
#           'volume_1day': '11260755.65673499',
#           'volume_7day': '75208268.104549205198813373'},
#  'CHL': [],
#  'CMT': {'24H_fluctate': '0.1',
#          '24H_fluctate_rate': '0.39',
#          'average_price': '25.8816',
#          'buy_price': '25.4',
#          'closing_price': '25.3',
#          'max_price': '26.7',
#          'min_price': '24.7',
#          'opening_price': '25.2',
#          'sell_price': '25.6',
#          'units_traded': '5535907.5962618',
#          'volume_1day': '5535907.5962618',
#          'volume_7day': '45426420.445349339087497181'},
#  'CTXC': {'24H_fluctate': '-2',
#           '24H_fluctate_rate': '-1.81',
#           'average_price': '109.3123',
#           'buy_price': '107',
#           'closing_price': '108',
#           'max_price': '113',
#           'min_price': '105',
#           'opening_price': '110',
#           'sell_price': '108',
#           'units_traded': '546136.04429439',
#           'volume_1day': '546136.04429439',
#           'volume_7day': '11567428.768417040273411807'},
#  'DASH': {'24H_fluctate': '-1300',
#           '24H_fluctate_rate': '-1.74',
#           'average_price': '74349.6129',
#           'buy_price': '73000',
#           'closing_price': '73200',
#           'max_price': '76800',
#           'min_price': '72100',
#           'opening_price': '74500',
#           'sell_price': '73200',
#           'units_traded': '6168535.24686515',
#           'volume_1day': '6168535.24686515',
#           'volume_7day': '37319512.5993393'},
#  'ELF': {'24H_fluctate': '2',
#          '24H_fluctate_rate': '1.81',
#          'average_price': '115.1668',
#          'buy_price': '111',
#          'closing_price': '112',
#          'max_price': '125',
#          'min_price': '108',
#          'opening_price': '110',
#          'sell_price': '112',
#          'units_traded': '3910432.16939922',
#          'volume_1day': '3910432.16939922',
#          'volume_7day': '16217838.297965019537578241'},
#  'ENJ': {'24H_fluctate': '0.7',
#          '24H_fluctate_rate': '2.22',
#          'average_price': '32.7154',
#          'buy_price': '32.4',
#          'closing_price': '32.2',
#          'max_price': '34.2',
#          'min_price': '31.4',
#          'opening_price': '31.5',
#          'sell_price': '33.5',
#          'units_traded': '681717.3198',
#          'volume_1day': '681717.3198',
#          'volume_7day': '10017816.050284802878061005'},
#  'EOS': {'24H_fluctate': '-92',
#          '24H_fluctate_rate': '-3.61',
#          'average_price': '2487.4556',
#          'buy_price': '2450',
#          'closing_price': '2450',
#          'max_price': '2559',
#          'min_price': '2404',
#          'opening_price': '2542',
#          'sell_price': '2451',
#          'units_traded': '1964320.05288497',
#          'volume_1day': '1964320.05288497',
#          'volume_7day': '9804321.54243789'},
#  'EOSDAC': [],
#  'ETC': {'24H_fluctate': '-150',
#          '24H_fluctate_rate': '-3.37',
#          'average_price': '4349.5404',
#          'buy_price': '4291',
#          'closing_price': '4298',
#          'max_price': '4474',
#          'min_price': '4219',
#          'opening_price': '4448',
#          'sell_price': '4300',
#          'units_traded': '54147.79517762',
#          'volume_1day': '54147.79517762',
#          'volume_7day': '305199.499613475489009608'},
#  'ETH': {'24H_fluctate': '-3700',
#          '24H_fluctate_rate': '-3.11',
#          'average_price': '116545.8529',
#          'buy_price': '115000',
#          'closing_price': '115000',
#          'max_price': '119800',
#          'min_price': '112800',
#          'opening_price': '118700',
#          'sell_price': '115100',
#          'units_traded': '95779.31920519',
#          'volume_1day': '95779.31920519',
#          'volume_7day': '430014.441714896396360074'},
#  'ETHOS': {'24H_fluctate': '11',
#            '24H_fluctate_rate': '7.00',
#            'average_price': '167.7575',
#            'buy_price': '168',
#            'closing_price': '168',
#            'max_price': '183',
#            'min_price': '146',
#            'opening_price': '157',
#            'sell_price': '169',
#            'units_traded': '5203824.55863667',
#            'volume_1day': '5203824.55863667',
#            'volume_7day': '28264476.33353831'},
#  'ETZ': {'24H_fluctate': '8',
#          '24H_fluctate_rate': '6.61',
#          'average_price': '132.0329',
#          'buy_price': '128',
#          'closing_price': '129',
#          'max_price': '148',
#          'min_price': '121',
#          'opening_price': '121',
#          'sell_price': '129',
#          'units_traded': '12284658.95587147',
#          'volume_1day': '12284658.95587147',
#          'volume_7day': '26065638.741688197538683689'},
#  'GNT': {'24H_fluctate': '-3.6',
#          '24H_fluctate_rate': '-5.52',
#          'average_price': '63.7094',
#          'buy_price': '61.6',
#          'closing_price': '61.6',
#          'max_price': '66.5',
#          'min_price': '61.1',
#          'opening_price': '65.2',
#          'sell_price': '62',
#          'units_traded': '1444379.93203568',
#          'volume_1day': '1444379.93203568',
#          'volume_7day': '7601084.815618884663091948'},
#  'GTO': {'24H_fluctate': '-0.3',
#          '24H_fluctate_rate': '-1.11',
#          'average_price': '27.1617',
#          'buy_price': '26.7',
#          'closing_price': '26.7',
#          'max_price': '28.5',
#          'min_price': '26.1',
#          'opening_price': '27',
#          'sell_price': '27.2',
#          'units_traded': '3880715.96057993',
#          'volume_1day': '3880715.96057993',
#          'volume_7day': '55889727.92632461'},
#  'HC': {'24H_fluctate': '-41',
#         '24H_fluctate_rate': '-3.85',
#         'average_price': '1022.0586',
#         'buy_price': '1010',
#         'closing_price': '1023',
#         'max_price': '1070',
#         'min_price': '990',
#         'opening_price': '1064',
#         'sell_price': '1024',
#         'units_traded': '88171.56200448',
#         'volume_1day': '88171.56200448',
#         'volume_7day': '1048204.74504903'},
#  'HORUS': [],
#  'ICX': {'24H_fluctate': '-8',
#          '24H_fluctate_rate': '-3.49',
#          'average_price': '225.1422',
#          'buy_price': '220',
#          'closing_price': '221',
#          'max_price': '245',
#          'min_price': '217',
#          'opening_price': '229',
#          'sell_price': '224',
#          'units_traded': '322698.01412162',
#          'volume_1day': '322698.01412162',
#          'volume_7day': '2521752.15602060774440284'},
#  'INS': {'24H_fluctate': '-4',
#          '24H_fluctate_rate': '-1.39',
#          'average_price': '287.1945',
#          'buy_price': '281',
#          'closing_price': '283',
#          'max_price': '296',
#          'min_price': '273',
#          'opening_price': '287',
#          'sell_price': '283',
#          'units_traded': '408872.45257473',
#          'volume_1day': '408872.45257473',
#          'volume_7day': '2887627.4930766507'},
#  'IOST': {'24H_fluctate': '-0.46',
#           '24H_fluctate_rate': '-7.18',
#           'average_price': '6.096',
#           'buy_price': '5.89',
#           'closing_price': '5.94',
#           'max_price': '6.47',
#           'min_price': '5.77',
#           'opening_price': '6.4',
#           'sell_price': '5.94',
#           'units_traded': '27159892.18756515',
#           'volume_1day': '27159892.18756515',
#           'volume_7day': '145300509.325806974381241693'},
#  'ITC': {'24H_fluctate': '-5',
#          '24H_fluctate_rate': '-4.42',
#          'average_price': '110.0933',
#          'buy_price': '108',
#          'closing_price': '108',
#          'max_price': '114',
#          'min_price': '105',
#          'opening_price': '113',
#          'sell_price': '112',
#          'units_traded': '299189.37011818',
#          'volume_1day': '299189.37011818',
#          'volume_7day': '2902563.728319016268785141'},
#  'KNC': {'24H_fluctate': '-2',
#          '24H_fluctate_rate': '-1.51',
#          'average_price': '132.478',
#          'buy_price': '129',
#          'closing_price': '130',
#          'max_price': '136',
#          'min_price': '129',
#          'opening_price': '132',
#          'sell_price': '130',
#          'units_traded': '667617.5628',
#          'volume_1day': '667617.5628',
#          'volume_7day': '4739370.036419997503071948'},
#  'LINK': {'24H_fluctate': '35',
#           '24H_fluctate_rate': '8.27',
#           'average_price': '450.3193',
#           'buy_price': '458',
#           'closing_price': '458',
#           'max_price': '499',
#           'min_price': '393',
#           'opening_price': '423',
#           'sell_price': '460',
#           'units_traded': '1884553.67598971',
#           'volume_1day': '1884553.67598971',
#           'volume_7day': '7638104.397861171388723166'},
#  'LOOM': {'24H_fluctate': '-4.6',
#           '24H_fluctate_rate': '-9.91',
#           'average_price': '43.849',
#           'buy_price': '42',
#           'closing_price': '41.8',
#           'max_price': '46.4',
#           'min_price': '41.8',
#           'opening_price': '46.4',
#           'sell_price': '43.8',
#           'units_traded': '1144238.64974518',
#           'volume_1day': '1144238.64974518',
#           'volume_7day': '6015607.319798338852353698'},
#  'LRC': {'24H_fluctate': '2.4',
#          '24H_fluctate_rate': '3.80',
#          'average_price': '65.6299',
#          'buy_price': '65.4',
#          'closing_price': '65.4',
#          'max_price': '71.9',
#          'min_price': '62.2',
#          'opening_price': '63',
#          'sell_price': '65.7',
#          'units_traded': '34126070.18742961',
#          'volume_1day': '34126070.18742961',
#          'volume_7day': '420037734.110144589561015935'},
#  'LTC': {'24H_fluctate': '-480',
#          '24H_fluctate_rate': '-1.39',
#          'average_price': '34103.8089',
#          'buy_price': '33840',
#          'closing_price': '33890',
#          'max_price': '34870',
#          'min_price': '33500',
#          'opening_price': '34370',
#          'sell_price': '33920',
#          'units_traded': '6927.64607364',
#          'volume_1day': '6927.64607364',
#          'volume_7day': '65663.67164165'},
#  'MCO': {'24H_fluctate': '13',
#          '24H_fluctate_rate': '0.60',
#          'average_price': '2212.026',
#          'buy_price': '2152',
#          'closing_price': '2164',
#          'max_price': '2409',
#          'min_price': '2151',
#          'opening_price': '2151',
#          'sell_price': '2163',
#          'units_traded': '22806.82972646',
#          'volume_1day': '22806.82972646',
#          'volume_7day': '96724.7559715'},
#  'MEETONE': [],
#  'MITH': {'24H_fluctate': '-2.3',
#           '24H_fluctate_rate': '-4.87',
#           'average_price': '46.7065',
#           'buy_price': '44.8',
#           'closing_price': '44.9',
#           'max_price': '48.3',
#           'min_price': '44.7',
#           'opening_price': '47.2',
#           'sell_price': '44.9',
#           'units_traded': '9765738.55085611',
#           'volume_1day': '9765738.55085611',
#           'volume_7day': '50345641.443735036629269078'},
#  'MTL': {'24H_fluctate': '0',
#          '24H_fluctate_rate': '0.00',
#          'average_price': '257.9736',
#          'buy_price': '250',
#          'closing_price': '251',
#          'max_price': '270',
#          'min_price': '244',
#          'opening_price': '251',
#          'sell_price': '259',
#          'units_traded': '319298.4595672',
#          'volume_1day': '319298.4595672',
#          'volume_7day': '5399739.13337233'},
#  'OCN': {'24H_fluctate': '-0.24',
#          '24H_fluctate_rate': '-9.30',
#          'average_price': '2.5379',
#          'buy_price': '2.33',
#          'closing_price': '2.34',
#          'max_price': '2.64',
#          'min_price': '2.3',
#          'opening_price': '2.58',
#          'sell_price': '2.34',
#          'units_traded': '33212457.49806245',
#          'volume_1day': '33212457.49806245',
#          'volume_7day': '212484388.387627052039125054'},
#  'OMG': {'24H_fluctate': '-27',
#          '24H_fluctate_rate': '-2.18',
#          'average_price': '1221.0377',
#          'buy_price': '1207',
#          'closing_price': '1207',
#          'max_price': '1251',
#          'min_price': '1185',
#          'opening_price': '1234',
#          'sell_price': '1216',
#          'units_traded': '159188512.04520203',
#          'volume_1day': '159188512.04520203',
#          'volume_7day': '487147029.181585184328980677'},
#  'PAY': {'24H_fluctate': '16',
#          '24H_fluctate_rate': '5.86',
#          'average_price': '291.5862',
#          'buy_price': '288',
#          'closing_price': '289',
#          'max_price': '324',
#          'min_price': '268',
#          'opening_price': '273',
#          'sell_price': '289',
#          'units_traded': '6798533.14470767',
#          'volume_1day': '6798533.14470767',
#          'volume_7day': '117908691.324702434199370868'},
#  'PIVX': {'24H_fluctate': '-3',
#           '24H_fluctate_rate': '-0.40',
#           'average_price': '741.4483',
#           'buy_price': '731',
#           'closing_price': '732',
#           'max_price': '766',
#           'min_price': '708',
#           'opening_price': '735',
#           'sell_price': '740',
#           'units_traded': '99859.17952937',
#           'volume_1day': '99859.17952937',
#           'volume_7day': '2932938.58820418'},
#  'PLY': {'24H_fluctate': '-1.5',
#          '24H_fluctate_rate': '-5.08',
#          'average_price': '28.5762',
#          'buy_price': '27.8',
#          'closing_price': '28',
#          'max_price': '29.9',
#          'min_price': '27.2',
#          'opening_price': '29.5',
#          'sell_price': '28.2',
#          'units_traded': '4881595.26932712',
#          'volume_1day': '4881595.26932712',
#          'volume_7day': '32968651.316679626'},
#  'POLY': {'24H_fluctate': '-8',
#           '24H_fluctate_rate': '-6.83',
#           'average_price': '112.8918',
#           'buy_price': '109',
#           'closing_price': '109',
#           'max_price': '120',
#           'min_price': '108',
#           'opening_price': '117',
#           'sell_price': '111',
#           'units_traded': '1477242.55199261',
#           'volume_1day': '1477242.55199261',
#           'volume_7day': '6474032.492128878752046145'},
#  'POWR': {'24H_fluctate': '1',
#           '24H_fluctate_rate': '1.14',
#           'average_price': '89.1681',
#           'buy_price': '87.6',
#           'closing_price': '88',
#           'max_price': '92.9',
#           'min_price': '85.1',
#           'opening_price': '87',
#           'sell_price': '88.7',
#           'units_traded': '4164215.70335574',
#           'volume_1day': '4164215.70335574',
#           'volume_7day': '40141107.65658265'},
#  'PPT': {'24H_fluctate': '-41',
#          '24H_fluctate_rate': '-3.05',
#          'average_price': '1336.6261',
#          'buy_price': '1280',
#          'closing_price': '1300',
#          'max_price': '1416',
#          'min_price': '1300',
#          'opening_price': '1341',
#          'sell_price': '1299',
#          'units_traded': '21671.62922233',
#          'volume_1day': '21671.62922233',
#          'volume_7day': '506961.49761665'},
#  'PST': {'24H_fluctate': '-0.9',
#          '24H_fluctate_rate': '-0.93',
#          'average_price': '96.8142',
#          'buy_price': '95.1',
#          'closing_price': '95.1',
#          'max_price': '98.8',
#          'min_price': '93.6',
#          'opening_price': '96',
#          'sell_price': '96.5',
#          'units_traded': '625309.6304',
#          'volume_1day': '625309.6304',
#          'volume_7day': '9822373.940160081746785649'},
#  'QTUM': {'24H_fluctate': '-52',
#           '24H_fluctate_rate': '-2.51',
#           'average_price': '2039.554',
#           'buy_price': '2007',
#           'closing_price': '2012',
#           'max_price': '2150',
#           'min_price': '1970',
#           'opening_price': '2064',
#           'sell_price': '2012',
#           'units_traded': '225073.24614032',
#           'volume_1day': '225073.24614032',
#           'volume_7day': '1097391.62562657'},
#  'RDN': {'24H_fluctate': '0',
#          '24H_fluctate_rate': '0.00',
#          'average_price': '227.0637',
#          'buy_price': '223',
#          'closing_price': '223',
#          'max_price': '234',
#          'min_price': '219',
#          'opening_price': '223',
#          'sell_price': '227',
#          'units_traded': '499296.36494604',
#          'volume_1day': '499296.36494604',
#          'volume_7day': '8425800.328934199120712691'},
#  'REP': {'24H_fluctate': '290',
#          '24H_fluctate_rate': '2.30',
#          'average_price': '12832.226',
#          'buy_price': '12810',
#          'closing_price': '12890',
#          'max_price': '13700',
#          'min_price': '12100',
#          'opening_price': '12600',
#          'sell_price': '12890',
#          'units_traded': '201791.20379522',
#          'volume_1day': '201791.20379522',
#          'volume_7day': '1290823.926167940556293053'},
#  'RNT': {'24H_fluctate': '1.9',
#          '24H_fluctate_rate': '2.74',
#          'average_price': '70.604',
#          'buy_price': '70.3',
#          'closing_price': '71.2',
#          'max_price': '71.9',
#          'min_price': '69',
#          'opening_price': '69.3',
#          'sell_price': '71.1',
#          'units_traded': '3571156.52378579',
#          'volume_1day': '3571156.52378579',
#          'volume_7day': '63873676.903217874702176911'},
#  'ROM': {'24H_fluctate': '-0.01',
#          '24H_fluctate_rate': '-11.11',
#          'average_price': '0.0864',
#          'buy_price': '0.08',
#          'closing_price': '0.08',
#          'max_price': '0.09',
#          'min_price': '0.08',
#          'opening_price': '0.09',
#          'sell_price': '0.09',
#          'units_traded': '1084615686.20181111',
#          'volume_1day': '1084615686.20181111',
#          'volume_7day': '12188964195.656575555444444436'},
#  'SALT': {'24H_fluctate': '-6',
#           '24H_fluctate_rate': '-2.51',
#           'average_price': '235.1245',
#           'buy_price': '230',
#           'closing_price': '233',
#           'max_price': '243',
#           'min_price': '223',
#           'opening_price': '239',
#           'sell_price': '233',
#           'units_traded': '641788.44228501',
#           'volume_1day': '641788.44228501',
#           'volume_7day': '4908323.15439428'},
#  'SNT': {'24H_fluctate': '0.1',
#          '24H_fluctate_rate': '0.48',
#          'average_price': '20.9048',
#          'buy_price': '20.8',
#          'closing_price': '20.8',
#          'max_price': '21.5',
#          'min_price': '20.2',
#          'opening_price': '20.7',
#          'sell_price': '20.9',
#          'units_traded': '21083799.26364481',
#          'volume_1day': '21083799.26364481',
#          'volume_7day': '162342961.910510216947588824'},
#  'STEEM': {'24H_fluctate': '6',
#            '24H_fluctate_rate': '1.91',
#            'average_price': '323.8208',
#            'buy_price': '319',
#            'closing_price': '320',
#            'max_price': '338',
#            'min_price': '311',
#            'opening_price': '314',
#            'sell_price': '322',
#            'units_traded': '1238287.24860317',
#            'volume_1day': '1238287.24860317',
#            'volume_7day': '30619362.4771082'},
#  'STRAT': {'24H_fluctate': '-14',
#            '24H_fluctate_rate': '-1.49',
#            'average_price': '927.0815',
#            'buy_price': '908',
#            'closing_price': '920',
#            'max_price': '970',
#            'min_price': '891',
#            'opening_price': '934',
#            'sell_price': '920',
#            'units_traded': '138334.81569217',
#            'volume_1day': '138334.81569217',
#            'volume_7day': '1675357.32720309'},
#  'THETA': {'24H_fluctate': '0.5',
#            '24H_fluctate_rate': '0.88',
#            'average_price': '57.4308',
#            'buy_price': '57.2',
#            'closing_price': '57.3',
#            'max_price': '61.1',
#            'min_price': '54.5',
#            'opening_price': '56.8',
#            'sell_price': '57.3',
#            'units_traded': '11948896.43717279',
#            'volume_1day': '11948896.43717279',
#            'volume_7day': '137497620.623402391595668157'},
#  'TMTG': {'24H_fluctate': '0.02',
#           '24H_fluctate_rate': '0.54',
#           'average_price': '3.756',
#           'buy_price': '3.66',
#           'closing_price': '3.7',
#           'max_price': '3.97',
#           'min_price': '3.63',
#           'opening_price': '3.68',
#           'sell_price': '3.7',
#           'units_traded': '158720805.08436238',
#           'volume_1day': '158720805.08436238',
#           'volume_7day': '1804802147.900235371389347755'},
#  'TRUE': {'24H_fluctate': '-4',
#           '24H_fluctate_rate': '-1.68',
#           'average_price': '238.7575',
#           'buy_price': '233',
#           'closing_price': '234',
#           'max_price': '244',
#           'min_price': '234',
#           'opening_price': '238',
#           'sell_price': '238',
#           'units_traded': '166283.24706667',
#           'volume_1day': '166283.24706667',
#           'volume_7day': '7096194.774050689086769364'},
#  'TRX': {'24H_fluctate': '-0.8',
#          '24H_fluctate_rate': '-2.65',
#          'average_price': '29.9573',
#          'buy_price': '29.3',
#          'closing_price': '29.3',
#          'max_price': '31.4',
#          'min_price': '28.1',
#          'opening_price': '30.1',
#          'sell_price': '29.4',
#          'units_traded': '2164909841.42431328',
#          'volume_1day': '2164909841.42431328',
#          'volume_7day': '4580637607.31130981'},
#  'VET': {'24H_fluctate': '-0.01',
#          '24H_fluctate_rate': '-0.23',
#          'average_price': '4.2774',
#          'buy_price': '4.18',
#          'closing_price': '4.22',
#          'max_price': '4.45',
#          'min_price': '4.16',
#          'opening_price': '4.23',
#          'sell_price': '4.22',
#          'units_traded': '74677280.28125646',
#          'volume_1day': '74677280.28125646',
#          'volume_7day': '1688380995.574177697215276127'},
#  'WAVES': {'24H_fluctate': '320',
#            '24H_fluctate_rate': '11.03',
#            'average_price': '3109.3824',
#            'buy_price': '3181',
#            'closing_price': '3221',
#            'max_price': '3316',
#            'min_price': '2850',
#            'opening_price': '2901',
#            'sell_price': '3221',
#            'units_traded': '433136.73685238',
#            'volume_1day': '433136.73685238',
#            'volume_7day': '3016554.16604767'},
#  'WAX': {'24H_fluctate': '0',
#          '24H_fluctate_rate': '0.00',
#          'average_price': '35.3353',
#          'buy_price': '34.9',
#          'closing_price': '35',
#          'max_price': '37.2',
#          'min_price': '34.2',
#          'opening_price': '35',
#          'sell_price': '35',
#          'units_traded': '2312895.3303631',
#          'volume_1day': '2312895.3303631',
#          'volume_7day': '22661748.74444521'},
#  'WET': {'24H_fluctate': '-0.2',
#          '24H_fluctate_rate': '-1.76',
#          'average_price': '11.2158',
#          'buy_price': '11',
#          'closing_price': '11.1',
#          'max_price': '11.7',
#          'min_price': '10.7',
#          'opening_price': '11.3',
#          'sell_price': '11.1',
#          'units_traded': '34590002.00978471',
#          'volume_1day': '34590002.00978471',
#          'volume_7day': '134456147.729493997151592521'},
#  'WTC': {'24H_fluctate': '8',
#          '24H_fluctate_rate': '0.74',
#          'average_price': '1095.3085',
#          'buy_price': '1065',
#          'closing_price': '1080',
#          'max_price': '1148',
#          'min_price': '1061',
#          'opening_price': '1072',
#          'sell_price': '1076',
#          'units_traded': '42878.93716633',
#          'volume_1day': '42878.93716633',
#          'volume_7day': '511033.366741901951337171'},
#  'XEM': {'24H_fluctate': '-2.9',
#          '24H_fluctate_rate': '-5.37',
#          'average_price': '52.4673',
#          'buy_price': '51',
#          'closing_price': '51.1',
#          'max_price': '56.2',
#          'min_price': '50',
#          'opening_price': '54',
#          'sell_price': '51.6',
#          'units_traded': '780450.65944511',
#          'volume_1day': '780450.65944511',
#          'volume_7day': '5737500.31070846'},
#  'XLM': {'24H_fluctate': '-7.5',
#          '24H_fluctate_rate': '-7.60',
#          'average_price': '95.2761',
#          'buy_price': '91.1',
#          'closing_price': '91.1',
#          'max_price': '99.9',
#          'min_price': '90.4',
#          'opening_price': '98.6',
#          'sell_price': '91.4',
#          'units_traded': '16080669.01611825',
#          'volume_1day': '16080669.01611825',
#          'volume_7day': '81871096.05392874'},
#  'XMR': {'24H_fluctate': '-600',
#          '24H_fluctate_rate': '-1.24',
#          'average_price': '48451.8965',
#          'buy_price': '47250',
#          'closing_price': '47750',
#          'max_price': '49750',
#          'min_price': '47320',
#          'opening_price': '48350',
#          'sell_price': '47700',
#          'units_traded': '1935634.19790879',
#          'volume_1day': '1935634.19790879',
#          'volume_7day': '27806570.024298385269'},
#  'XRP': {'24H_fluctate': '-7',
#          '24H_fluctate_rate': '-2.14',
#          'average_price': '322.7726',
#          'buy_price': '319',
#          'closing_price': '320',
#          'max_price': '332',
#          'min_price': '313',
#          'opening_price': '327',
#          'sell_price': '320',
#          'units_traded': '48308645.19872347',
#          'volume_1day': '48308645.19872347',
#          'volume_7day': '203009176.68785978'},
#  'XVG': {'24H_fluctate': '-0.05',
#          '24H_fluctate_rate': '-0.75',
#          'average_price': '6.6422',
#          'buy_price': '6.51',
#          'closing_price': '6.58',
#          'max_price': '6.8',
#          'min_price': '6.45',
#          'opening_price': '6.63',
#          'sell_price': '6.58',
#          'units_traded': '10709862.07023703',
#          'volume_1day': '10709862.07023703',
#          'volume_7day': '129736670.46340741'},
#  'ZEC': {'24H_fluctate': '-1000',
#          '24H_fluctate_rate': '-1.84',
#          'average_price': '54400.2735',
#          'buy_price': '53150',
#          'closing_price': '53150',
#          'max_price': '56400',
#          'min_price': '52950',
#          'opening_price': '54150',
#          'sell_price': '53250',
#          'units_traded': '10265475.48355454',
#          'volume_1day': '10265475.48355454',
#          'volume_7day': '63080775.91269792'},
#  'ZIL': {'24H_fluctate': '-1.6',
#          '24H_fluctate_rate': '-6.77',
#          'average_price': '22.872',
#          'buy_price': '21.9',
#          'closing_price': '22',
#          'max_price': '24.1',
#          'min_price': '21.3',
#          'opening_price': '23.6',
#          'sell_price': '22',
#          'units_traded': '73475599.08808771',
#          'volume_1day': '73475599.08808771',
#          'volume_7day': '419788830.013498944347'},
#  'ZRX': {'24H_fluctate': '-4',
#          '24H_fluctate_rate': '-1.42',
#          'average_price': '282.3737',
#          'buy_price': '278',
#          'closing_price': '277',
#          'max_price': '291',
#          'min_price': '276',
#          'opening_price': '281',
#          'sell_price': '279',
#          'units_traded': '250510.39494687',
#          'volume_1day': '250510.39494687',
#          'volume_7day': '5663615.411265400856955878'},
#  'date': '1548743704353'}

# %%
# 아래에 코드를 작성하세요.
for i in currency:
    
    if type(currency[i]) == dict:
        fluc = float(currency[i]['max_price'])-float(currency[i]['min_price'])
        if float(currency[i]['opening_price']) + fluc > float(currency[i]['max_price']):
            print('상승장')
        else:
            print('하락장')
# Out:
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 하락장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 하락장
# 상승장
# 상승장
# 상승장
